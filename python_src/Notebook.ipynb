# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
output5 = pd.read_table("../outputs/data/mixed_dynamics_50_0.500000_0.010000")
output1 = pd.read_table("../outputs/data/mixed_dynamics_50_0.500000_0.020000")
output0 = pd.read_table("../outputs/data/mixed_dynamics_50_0.500000_0.050000")
output4 = pd.read_table("../outputs/data/mixed_dynamics_50_0.500000_0.200000")
output5.sort_values('Temperature',inplace=True)
output1.sort_values('Temperature',inplace=True)
output0.sort_values('Temperature',inplace=True)
output4.sort_values('Temperature',inplace=True)

# %%
output1.head()
# Out:
#     Participation  Temperature  SquareEnergy  OpenSquares  TriadEnergy  \
# 0            0.02            0     -1.000000     0.020408    -1.000000
# 4            0.02           20     -1.000000    -0.013878    -1.000000
# 8            0.02           40      0.000191    -0.000423    -0.019592
# 12           0.02           60     -0.000185     0.000715    -0.019388
# 16           0.02           80     -0.003121     0.000177    -0.025714
#
#     TwoStars      Mean
# 0   0.020408  0.020408
# 4  -0.013878 -0.013878
# 8   0.000000  0.015510
# 12 -0.004150 -0.031837
# 16 -0.010204 -0.017143

# %%
triadEnergy_t = np.zeros((60,4))
triadEnergy_t[:,0] = output1['Temperature']
triadEnergy_t[:,1] = output1['TriadEnergy']
triadEnergy_t[:,2] = output5['TriadEnergy']
triadEnergy_t[:,3] = output0['TriadEnergy']

# %%
plt.plot(triadEnergy_t[:,0],triadEnergy_t[:,1:],'.')

# %%
tStars_t = np.zeros((60,4))
tStars_t[:,0] = output1['Temperature']
tStars_t[:,1] = output1['TwoStars']
tStars_t[:,2] = output5['TwoStars']
tStars_t[:,3] = output4['TwoStars']

# %%
plt.plot(tStars_t[:,0],tStars_t[:,1:],'.')

# %%
plt.plot(tStars_t[:,0],tStars_t[:,1:],'.')

# %%
out5 = pd.read_table("../outputs/data/mixed_dynamics_50_0.500000_1.000000")
out1 = pd.read_table("../outputs/data/mixed_dynamics_50_1.000000_1.000000")
out0 = pd.read_table("../outputs/data/mixed_dynamics_50_0.000000_1.000000")
out5.sort_values('Temperature',inplace=True)
out1.sort_values('Temperature',inplace=True)
out0.sort_values('Temperature',inplace=True)

# %%
plt.plot(out1['Temperature'],out1['TriadEnergy'],'.')

# %%
triadEnergy_s = np.zeros((60,4))
triadEnergy_s[:,0] = out1['Temperature']
triadEnergy_s[:,1] = out1['TriadEnergy']
triadEnergy_s[:,2] = out0['TriadEnergy']
triadEnergy_s[:,3] = out5['TriadEnergy']

# %%
plt.plot(triadEnergy_s[:,0],triadEnergy_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(triadEnergy_s[:,0],triadEnergy_s[:,2],linestyle='--',label="All Enmity")
plt.plot(triadEnergy_s[:,0],triadEnergy_s[:,3],'.',label="Random")
plt.legend()
title = "Quartic Balance Mean Value of Triad Product"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ij} \sigma_{jk} \sigma_{ki}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
SquareEnergy_s = np.zeros((60,4))
SquareEnergy_s[:,0] = out1['Temperature']
SquareEnergy_s[:,1] = out1['SquareEnergy']
SquareEnergy_s[:,2] = out0['SquareEnergy']
SquareEnergy_s[:,3] = out5['SquareEnergy']

# %%
plt.plot(SquareEnergy_s[:,0],SquareEnergy_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(SquareEnergy_s[:,0],SquareEnergy_s[:,2],linestyle='--',label="All Enmity")
plt.plot(SquareEnergy_s[:,0],SquareEnergy_s[:,3],'.',label="Random")
plt.legend()
title = "Quartic Balance Square Energy"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik} \sigma_{kj} \sigma_{jl} \sigma_{li}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
OpenSquare_s = np.zeros((60,4))
OpenSquare_s[:,0] = out1['Temperature']
OpenSquare_s[:,1] = out1['OpenSquares']
OpenSquare_s[:,2] = out0['OpenSquares']
OpenSquare_s[:,3] = out5['OpenSquares']

# %%
plt.plot(OpenSquare_s[:,0],OpenSquare_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(OpenSquare_s[:,0],OpenSquare_s[:,2],linestyle='--',label="All Enmity")
plt.plot(OpenSquare_s[:,0],OpenSquare_s[:,3],'.',label="Random")
plt.legend()
title = "Quartic Balance Open Squares"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik} \sigma_{il} \sigma_{lj}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
Mean_s = np.zeros((60,4))
Mean_s[:,0] = out1['Temperature']
Mean_s[:,1] = out1['Mean']
Mean_s[:,2] = out0['Mean']
Mean_s[:,3] = out5['Mean']

# %%
plt.plot(Mean_s[:,0],Mean_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(Mean_s[:,0],Mean_s[:,2],linestyle='--',label="All Enmity")
plt.plot(Mean_s[:,0],Mean_s[:,3],'.',label="Random")
plt.legend()
title = "Quartic Balance Links' Mean Sign"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
TStars_s = np.zeros((60,4))
TStars_s[:,0] = out1['Temperature']
TStars_s[:,1] = out1['TwoStars']
TStars_s[:,2] = out0['TwoStars']
TStars_s[:,3] = out5['TwoStars']

# %%
plt.plot(TStars_s[:,0],TStars_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(TStars_s[:,0],TStars_s[:,2],linestyle='--',label="All Enmity")
plt.plot(TStars_s[:,0],TStars_s[:,3],'.',label="Random")
plt.legend()
title = "Quartic Balance Two Stars Mean Value"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik} \sigma_{kj}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
out5 = pd.read_table("../outputs/data/mixed_dynamics_50_0.500000_0.100000")
out1 = pd.read_table("../outputs/data/mixed_dynamics_50_1.000000_0.100000")
out0 = pd.read_table("../outputs/data/mixed_dynamics_50_0.000000_0.100000")
out5.sort_values('Temperature',inplace=True)
out1.sort_values('Temperature',inplace=True)
out0.sort_values('Temperature',inplace=True)

# %%
triadEnergy_s = np.zeros((60,4))
triadEnergy_s[:,0] = out1['Temperature']
triadEnergy_s[:,1] = out1['TriadEnergy']
triadEnergy_s[:,2] = out0['TriadEnergy']
triadEnergy_s[:,3] = out5['TriadEnergy']

# %%
plt.plot(triadEnergy_s[:,0],triadEnergy_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(triadEnergy_s[:,0],triadEnergy_s[:,2],linestyle='--',label="All Enmity")
plt.plot(triadEnergy_s[:,0],triadEnergy_s[:,3],'.',label="Random")
plt.legend()
title = "Hybrid Balance Mean Value of Triad Product"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ij} \sigma_{jk} \sigma_{ki}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
SquareEnergy_s = np.zeros((60,4))
SquareEnergy_s[:,0] = out1['Temperature']
SquareEnergy_s[:,1] = out1['SquareEnergy']
SquareEnergy_s[:,2] = out0['SquareEnergy']
SquareEnergy_s[:,3] = out5['SquareEnergy']

# %%
plt.plot(SquareEnergy_s[:,0],SquareEnergy_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(SquareEnergy_s[:,0],SquareEnergy_s[:,2],linestyle='--',label="All Enmity")
plt.plot(SquareEnergy_s[:,0],SquareEnergy_s[:,3],'.',label="Random")
plt.legend()
title = "Hybrid Balance Square Energy"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik} \sigma_{kj} \sigma_{jl} \sigma_{li}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
OpenSquare_s = np.zeros((60,4))
OpenSquare_s[:,0] = out1['Temperature']
OpenSquare_s[:,1] = out1['OpenSquares']
OpenSquare_s[:,2] = out0['OpenSquares']
OpenSquare_s[:,3] = out5['OpenSquares']

# %%
plt.plot(OpenSquare_s[:,0],OpenSquare_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(OpenSquare_s[:,0],OpenSquare_s[:,2],linestyle='--',label="All Enmity")
plt.plot(OpenSquare_s[:,0],OpenSquare_s[:,3],'.',label="Random")
plt.legend()
title = "Hybrid Balance Open Squares"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik} \sigma_{il} \sigma_{lj}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
Mean_s = np.zeros((60,4))
Mean_s[:,0] = out1['Temperature']
Mean_s[:,1] = out1['Mean']
Mean_s[:,2] = out0['Mean']
Mean_s[:,3] = out5['Mean']

# %%
plt.plot(Mean_s[:,0],Mean_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(Mean_s[:,0],Mean_s[:,2],linestyle='--',label="All Enmity")
plt.plot(Mean_s[:,0],Mean_s[:,3],'.',label="Random")
plt.legend()
title = "Hybrid Balance Links' Mean Sign"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
TStars_s = np.zeros((60,4))
TStars_s[:,0] = out1['Temperature']
TStars_s[:,1] = out1['TwoStars']
TStars_s[:,2] = out0['TwoStars']
TStars_s[:,3] = out5['TwoStars']

# %%
plt.plot(TStars_s[:,0],TStars_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(TStars_s[:,0],TStars_s[:,2],linestyle='--',label="All Enmity")
plt.plot(TStars_s[:,0],TStars_s[:,3],'.',label="Random")
plt.legend()
title = "Hybrid Balance Two Stars Mean Value"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik} \sigma_{kj}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
out5 = pd.read_table("../outputs/data/mixed_dynamics_50_0.500000_0.000000")
out1 = pd.read_table("../outputs/data/mixed_dynamics_50_1.000000_0.000000")
out0 = pd.read_table("../outputs/data/mixed_dynamics_50_0.000000_0.000000")
out5.sort_values('Temperature',inplace=True)
out1.sort_values('Temperature',inplace=True)
out0.sort_values('Temperature',inplace=True)

# %%
triadEnergy_s = np.zeros((60,4))
triadEnergy_s[:,0] = out1['Temperature']
triadEnergy_s[:,1] = out1['TriadEnergy']
triadEnergy_s[:,2] = out0['TriadEnergy']
triadEnergy_s[:,3] = out5['TriadEnergy']

# %%
plt.plot(triadEnergy_s[:,0],triadEnergy_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(triadEnergy_s[:,0],triadEnergy_s[:,2],linestyle='--',label="All Enmity")
plt.plot(triadEnergy_s[:,0],triadEnergy_s[:,3],'.',label="Random")
plt.legend()
title = "Triadic Balance Mean Value of Triad Product"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ij} \sigma_{jk} \sigma_{ki}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
SquareEnergy_s = np.zeros((60,4))
SquareEnergy_s[:,0] = out1['Temperature']
SquareEnergy_s[:,1] = out1['SquareEnergy']
SquareEnergy_s[:,2] = out0['SquareEnergy']
SquareEnergy_s[:,3] = out5['SquareEnergy']

# %%
plt.plot(SquareEnergy_s[:,0],SquareEnergy_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(SquareEnergy_s[:,0],SquareEnergy_s[:,2],linestyle='--',label="All Enmity")
plt.plot(SquareEnergy_s[:,0],SquareEnergy_s[:,3],'.',label="Random")
plt.legend()
title = "Triadic Balance Square Energy"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik} \sigma_{kj} \sigma_{jl} \sigma_{li}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
OpenSquare_s = np.zeros((60,4))
OpenSquare_s[:,0] = out1['Temperature']
OpenSquare_s[:,1] = out1['OpenSquares']
OpenSquare_s[:,2] = out0['OpenSquares']
OpenSquare_s[:,3] = out5['OpenSquares']

# %%
plt.plot(OpenSquare_s[:,0],OpenSquare_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(OpenSquare_s[:,0],OpenSquare_s[:,2],linestyle='--',label="All Enmity")
plt.plot(OpenSquare_s[:,0],OpenSquare_s[:,3],'.',label="Random")
plt.legend()
title = "Triadic Balance Open Squares"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik} \sigma_{il} \sigma_{lj}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
Mean_s = np.zeros((60,4))
Mean_s[:,0] = out1['Temperature']
Mean_s[:,1] = out1['Mean']
Mean_s[:,2] = out0['Mean']
Mean_s[:,3] = out5['Mean']

# %%
plt.plot(Mean_s[:,0],Mean_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(Mean_s[:,0],Mean_s[:,2],linestyle='--',label="All Enmity")
plt.plot(Mean_s[:,0],Mean_s[:,3],'.',label="Random")
plt.legend()
title = "Triadic Balance Links' Mean Sign"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)

# %%
TStars_s = np.zeros((60,4))
TStars_s[:,0] = out1['Temperature']
TStars_s[:,1] = out1['TwoStars']
TStars_s[:,2] = out0['TwoStars']
TStars_s[:,3] = out5['TwoStars']

# %%
plt.plot(TStars_s[:,0],TStars_s[:,1],linestyle='-.',label="All Frienship")
plt.plot(TStars_s[:,0],TStars_s[:,2],linestyle='--',label="All Enmity")
plt.plot(TStars_s[:,0],TStars_s[:,3],'.',label="Random")
plt.legend()
title = "Triadic Balance Two Stars Mean Value"
plt.title(title)
plt.xlabel("Temperature")
plt.ylabel(r"$\langle{\sigma_{ik} \sigma_{kj}}\rangle$")
plt.tight_layout()
plt.savefig("../outputs/plots/" + title + ".jpg", dpi=250)
